# %% [markdown]
# #### About this Notebook
# In this notebook, we learn how to use scikit-learn to implement simple linear regression. We download a dataset that is related to fuel consumption and Carbon dioxide emission of cars. Then, we split our data into training and test sets, create a model using training set, Evaluate your model using test set, and finally use model to predict unknown value

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pylab as pl
# %matplotlib inline

# %% [markdown]
# ## Understanding the Data
#
# ### `FuelConsumption.csv`:
# We have downloaded a fuel consumption dataset, **`FuelConsumption.csv`**, which contains model-specific fuel consumption ratings and estimated carbon dioxide emissions for new light-duty vehicles for retail sale in Canada. [Dataset source](http://open.canada.ca/data/en/dataset/98f1a129-f628-4ce4-b24d-6f16bf24dd64)
#
# - **MODELYEAR** e.g. 2014
# - **MAKE** e.g. Acura
# - **MODEL** e.g. ILX
# - **VEHICLE CLASS** e.g. SUV
# - **ENGINE SIZE** e.g. 4.7
# - **CYLINDERS** e.g 6
# - **TRANSMISSION** e.g. A6
# - **FUEL CONSUMPTION in CITY(L/100 km)** e.g. 9.9
# - **FUEL CONSUMPTION in HWY (L/100 km)** e.g. 8.9
# - **FUEL CONSUMPTION COMB (L/100 km)** e.g. 9.2
# - **CO2 EMISSIONS (g/km)** e.g. 182   --> low --> 0

# %% [markdown]
# ## Reading the data

# %%
# !wget -O FuelConsumption.csv https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/FuelConsumptionCo2.csv
# Out:
# --2020-08-06 17:02:37--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/FuelConsumptionCo2.csv
# wget: Cannot read /home/shahriar/.netrc (Permission denied).
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72629 (71K) [text/csv]
# Saving to: ‘FuelConsumption.csv’
#
# FuelConsumption.csv 100%[===================>]  70.93K   150KB/s    in 0.5s
#
# 2020-08-06 17:02:39 (150 KB/s) - ‘FuelConsumption.csv’ saved [72629/72629]

# %%
data_frame = pd.read_csv("FuelConsumption.csv")

# take a look at the dataset
data_frame.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# 1                   9.6                        29           221
# 2                   5.9                        48           136
# 3                  11.1                        25           255
# 4                  10.6                        27           244

# %% [markdown]
# ## Data exploration
# Let's have a descriptive exploration on our data

# %%
# summarize data
data_frame.describe()
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# 25%               7.500000              9.000000                 21.000000
# 50%               8.800000             10.900000                 26.000000
# 75%              10.850000             13.350000                 31.000000
# max              20.500000             25.800000                 60.000000
#
#        CO2EMISSIONS
# count   1067.000000
# mean     256.228679
# std       63.372304
# min      108.000000
# 25%      207.000000
# 50%      251.000000
# 75%      294.000000
# max      488.000000

# %% [markdown]
# ### Let's select some features to explore more

# %%
new_dataframe = data_frame[['ENGINESIZE', 'CYLINDERS', 'FUELCONSUMPTION_COMB', 'CO2EMISSIONS']]

# new_dataframe.head(9).describe()
new_dataframe.head(9)
# Out:
#    ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  CO2EMISSIONS
# 0         2.0          4                   8.5           196
# 1         2.4          4                   9.6           221
# 2         1.5          4                   5.9           136
# 3         3.5          6                  11.1           255
# 4         3.5          6                  10.6           244
# 5         3.5          6                  10.0           230
# 6         3.5          6                  10.1           232
# 7         3.7          6                  11.1           255
# 8         3.7          6                  11.6           267

# %% [markdown]
# ### Plot each of these features

# %%
figure1 = new_dataframe[['ENGINESIZE', 'CYLINDERS', 'FUELCONSUMPTION_COMB', 'CO2EMISSIONS']]
figure1.hist()
plt.show()

# %% [markdown]
# Now plot each of these features vs the emission to see how linear their relation is

# %%
plt.scatter(new_dataframe.FUELCONSUMPTION_COMB, new_dataframe.CO2EMISSIONS)
plt.xlabel("FUELCONSUMPTION_COMB")
plt.ylabel("CO2Emmisions")
plt.show()

# %%
plt.scatter(new_dataframe.CYLINDERS, new_dataframe.CO2EMISSIONS)
plt.xlabel("CYLINDERS")
plt.ylabel("CO2EMISSIONS")
plt.show()

# %%
plt.scatter(new_dataframe.ENGINESIZE, new_dataframe.CO2EMISSIONS, color='blue')
plt.xlabel("ENGINESIZE")
plt.ylabel("CO2EMISSIONS")
plt.grid()
plt.show()

# %% [markdown]
# #### Creating train and test dataset
# Train/Test Split involves splitting the dataset into training and testing sets respectively, which are mutually exclusive. After which, you train with the training set and test with the testing set.
# This will provide a more accurate evaluation on out-of-sample accuracy because the testing dataset is not part of the dataset that have been used to train the data. It is more realistic for real world problems.
#
# This means that we know the outcome of each data point in this dataset, making it great to test with! And since this data has not been used to train the model, the model has no knowledge of the outcome of these data points. So, in essence, it is truly an out-of-sample testing.

# %%
msk = np.random.rand(len(data_frame)) < 0.8
training_set = data_frame[msk]
testing_set = data_frame[~msk]
testing_set
# Out:
#       MODELYEAR          MAKE                        MODEL  \
# 2          2014         ACURA                   ILX HYBRID
# 15         2014  ASTON MARTIN                   V8 VANTAGE
# 21         2014          AUDI                   A4 QUATTRO
# 22         2014          AUDI         A5 CABRIOLET QUATTRO
# 27         2014          AUDI  A6 QUATTRO TDI CLEAN DIESEL
# 29         2014          AUDI  A7 QUATTRO TDI CLEAN DIESEL
# 34         2014          AUDI                          A8L
# 38         2014          AUDI                           Q5
# 47         2014          AUDI                           R8
# 49         2014          AUDI                    R8 SPYDER
# 51         2014          AUDI                    R8 SPYDER
# 53         2014          AUDI                RS5 CABRIOLET
# 64         2014          AUDI             TT COUPE QUATTRO
# 72         2014       BENTLEY              CONTINENTAL GTC
# 77         2014           BMW                         320i
# 78         2014           BMW                  320i xDRIVE
# 92         2014           BMW                   428i COUPE
# 97         2014           BMW            435i xDRIVE COUPE
# 103        2014           BMW                  550i xDRIVE
# 104        2014           BMW     550i xDRIVE GRAN TURISMO
# 123        2014           BMW                 M6 CABRIOLET
# 127        2014           BMW                 X1 xDRIVE35i
# 133        2014           BMW                 X6 xDRIVE35i
# 138        2014           BMW                 Z4 sDRIVE35i
# 141        2014         BUICK                  ENCLAVE AWD
# 144        2014         BUICK                     LACROSSE
# 153        2014         BUICK                       VERANO
# 161        2014      CADILLAC                      ATS AWD
# 166        2014      CADILLAC                CTS SEDAN AWD
# 170        2014      CADILLAC              CTS SPORT WAGON
# ...         ...           ...                          ...
# 941        2014           SRT              VIPER GTS COUPE
# 944        2014        SUBARU                 FORESTER AWD
# 945        2014        SUBARU                 FORESTER AWD
# 946        2014        SUBARU                 FORESTER AWD
# 949        2014        SUBARU                  IMPREZA AWD
# 951        2014        SUBARU            IMPREZA WAGON AWD
# 958        2014        SUBARU                  OUTBACK AWD
# 962        2014        SUBARU             XV CROSSTREK AWD
# 984        2014        TOYOTA               HIGHLANDER AWD
# 989        2014        TOYOTA                      PRIUS v
# 991        2014        TOYOTA                     RAV4 AWD
# 994        2014        TOYOTA                       SIENNA
# 998        2014        TOYOTA                       TACOMA
# 999        2014        TOYOTA                   TACOMA 4WD
# 1001       2014        TOYOTA                   TACOMA 4WD
# 1007       2014        TOYOTA                   TUNDRA 4WD
# 1008       2014        TOYOTA                        VENZA
# 1010       2014        TOYOTA                    VENZA 4WD
# 1016       2014    VOLKSWAGEN                       BEETLE
# 1017       2014    VOLKSWAGEN                       BEETLE
# 1018       2014    VOLKSWAGEN                       BEETLE
# 1030       2014    VOLKSWAGEN                   GOLF WAGON
# 1031       2014    VOLKSWAGEN                   GOLF WAGON
# 1035       2014    VOLKSWAGEN                        JETTA
# 1037       2014    VOLKSWAGEN                        JETTA
# 1046       2014    VOLKSWAGEN                       PASSAT
# 1049       2014    VOLKSWAGEN      PASSAT TDI CLEAN DIESEL
# 1058       2014         VOLVO                      S60 AWD
# 1060       2014         VOLVO                      S80 AWD
# 1061       2014         VOLVO                         XC60
#
#                   VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  \
# 2                      COMPACT         1.5          4          AV7        Z
# 15                  TWO-SEATER         4.7          8           M6        Z
# 21                     COMPACT         2.0          4           M6        Z
# 22                  SUBCOMPACT         2.0          4          AS8        Z
# 27                    MID-SIZE         3.0          6          AS8        D
# 29                    MID-SIZE         3.0          6          AS8        D
# 34                   FULL-SIZE         4.0          8          AS8        Z
# 38                 SUV - SMALL         2.0          4          AS8        Z
# 47                  TWO-SEATER         5.2         10           M6        Z
# 49                  TWO-SEATER         4.2          8           M6        Z
# 51                  TWO-SEATER         5.2         10           M6        Z
# 53                  SUBCOMPACT         4.2          8           A7        Z
# 64                  SUBCOMPACT         2.0          4           A6        Z
# 72                  SUBCOMPACT         4.0          8          AS8        Z
# 77                     COMPACT         2.0          4           M6        Z
# 78                     COMPACT         2.0          4           A8        Z
# 92                     COMPACT         2.0          4           M6        Z
# 97                     COMPACT         3.0          6           M6        Z
# 103                   MID-SIZE         4.4          8           A8        Z
# 104                  FULL-SIZE         4.4          8           A8        Z
# 123                 SUBCOMPACT         4.4          8           M6        Z
# 127                SUV - SMALL         3.0          6           A6        Z
# 133             SUV - STANDARD         3.0          6           A8        Z
# 138                 TWO-SEATER         3.0          6           M6        Z
# 141             SUV - STANDARD         3.6          6           A6        X
# 144                   MID-SIZE         3.6          6          AS6        X
# 153                    COMPACT         2.0          4          AS6        Z
# 161                    COMPACT         3.6          6          AS6        X
# 166                   MID-SIZE         2.0          4          AS6        Z
# 170      STATION WAGON - SMALL         3.6          6          AS6        X
# ...                        ...         ...        ...          ...      ...
# 941                 TWO-SEATER         8.4         10           M6        Z
# 944                SUV - SMALL         2.0          4           AV        Z
# 945                SUV - SMALL         2.5          4           AV        X
# 946                SUV - SMALL         2.5          4           M6        X
# 949                    COMPACT         2.5          4           M5        Z
# 951      STATION WAGON - SMALL         2.0          4           AV        X
# 958                SUV - SMALL         2.5          4           AV        X
# 962                SUV - SMALL         2.0          4           AV        X
# 984             SUV - STANDARD         3.5          6          AS6        X
# 989   STATION WAGON - MID-SIZE         1.8          4           AV        X
# 991                SUV - SMALL         2.5          4          AS6        X
# 994                    MINIVAN         3.5          6          AS6        X
# 998       PICKUP TRUCK - SMALL         4.0          6           M6        X
# 999       PICKUP TRUCK - SMALL         2.7          4           A4        X
# 1001      PICKUP TRUCK - SMALL         4.0          6           A5        X
# 1007   PICKUP TRUCK - STANDARD         5.7          8          AS6        X
# 1008               SUV - SMALL         2.7          4          AS6        X
# 1010               SUV - SMALL         2.7          4          AS6        X
# 1016                   COMPACT         2.0          4           A6        Z
# 1017                   COMPACT         2.0          4           M6        Z
# 1018                   COMPACT         2.5          5           A6        X
# 1030     STATION WAGON - SMALL         2.5          5           A6        X
# 1031     STATION WAGON - SMALL         2.5          5           M5        X
# 1035                   COMPACT         1.8          4           M5        X
# 1037                   COMPACT         2.0          4           M5        X
# 1046                  MID-SIZE         2.5          5           M5        X
# 1049                  MID-SIZE         2.0          4           M6        D
# 1058                   COMPACT         3.0          6          AS6        X
# 1060                  MID-SIZE         3.0          6          AS6        X
# 1061               SUV - SMALL         3.2          6          AS6        X
#
#       FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 2                      6.0                  5.8                   5.9
# 15                    18.1                 12.2                  15.4
# 21                    10.8                  7.5                   9.3
# 22                    11.5                  8.1                  10.0
# 27                     9.8                  6.4                   8.3
# 29                     9.8                  6.4                   8.3
# 34                    14.7                  9.7                  12.5
# 38                    12.0                  8.5                  10.4
# 47                    21.1                 13.8                  17.8
# 49                    21.2                 13.4                  17.7
# 51                    21.1                 13.8                  17.8
# 53                    15.2                 11.3                  13.4
# 64                    10.4                  7.6                   9.1
# 72                    16.7                 10.6                  14.0
# 77                    10.4                  6.7                   8.7
# 78                    10.2                  7.0                   8.8
# 92                    10.4                  6.7                   8.7
# 97                    11.9                  8.3                  10.3
# 103                   14.4                  9.6                  12.2
# 104                   15.0                  9.8                  12.7
# 123                   16.2                 10.9                  13.8
# 127                   13.2                  8.9                  11.3
# 133                   13.6                  9.8                  11.9
# 138                   12.7                  9.0                  11.0
# 141                   14.6                 10.2                  12.6
# 144                   13.7                  8.7                  11.5
# 153                   11.5                  7.9                   9.9
# 161                   13.1                  9.0                  11.3
# 166                   12.6                  8.5                  10.8
# 170                   13.3                  8.9                  11.3
# ...                    ...                  ...                   ...
# 941                   20.0                 13.0                  16.9
# 944                   10.2                  8.6                   9.5
# 945                    9.6                  7.4                   8.6
# 946                   10.9                  8.3                   9.7
# 949                   12.6                  9.5                  11.2
# 951                    8.7                  6.6                   7.8
# 958                    9.9                  7.8                   9.0
# 962                    9.5                  7.2                   8.5
# 984                   13.0                  9.7                  11.5
# 989                    5.3                  5.8                   5.5
# 991                   10.4                  8.1                   9.4
# 994                   12.9                  9.4                  11.3
# 998                   14.5                 11.3                  13.1
# 999                   13.1                 10.5                  11.9
# 1001                  14.7                 11.5                  13.3
# 1007                  18.1                 13.9                  16.2
# 1008                  11.4                  8.2                  10.0
# 1010                  11.6                  8.5                  10.2
# 1016                  10.3                  7.7                   9.1
# 1017                  10.8                  7.6                   9.4
# 1018                  10.9                  8.4                   9.8
# 1030                  11.0                  7.7                   9.5
# 1031                  11.2                  7.3                   9.4
# 1035                   9.4                  6.7                   8.2
# 1037                  10.4                  7.2                   9.0
# 1046                  11.4                  7.8                   9.8
# 1049                   8.0                  5.4                   6.8
# 1058                  13.2                  9.5                  11.5
# 1060                  13.2                  9.5                  11.5
# 1061                  13.0                  8.9                  11.2
#
#       FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 2                           48           136
# 15                          18           354
# 21                          30           214
# 22                          28           230
# 27                          34           224
# 29                          34           224
# 34                          23           288
# 38                          27           239
# 47                          16           409
# 49                          16           407
# 51                          16           409
# 53                          21           308
# 64                          31           209
# 72                          20           322
# 77                          32           200
# 78                          32           202
# 92                          32           200
# 97                          27           237
# 103                         23           281
# 104                         22           292
# 123                         20           317
# 127                         25           260
# 133                         24           274
# 138                         26           253
# 141                         22           290
# 144                         25           264
# 153                         29           228
# 161                         25           260
# 166                         26           248
# 170                         25           260
# ...                        ...           ...
# 941                         17           389
# 944                         30           218
# 945                         33           198
# 946                         29           223
# 949                         25           258
# 951                         36           179
# 958                         31           207
# 962                         33           196
# 984                         25           264
# 989                         51           126
# 991                         30           216
# 994                         25           260
# 998                         22           301
# 999                         24           274
# 1001                        21           306
# 1007                        17           373
# 1008                        28           230
# 1010                        28           235
# 1016                        31           209
# 1017                        30           216
# 1018                        29           225
# 1030                        30           218
# 1031                        30           216
# 1035                        34           189
# 1037                        31           207
# 1046                        29           225
# 1049                        42           184
# 1058                        25           264
# 1060                        25           264
# 1061                        25           258
#
# [225 rows x 13 columns]

# %% [markdown]
# ### Simple Regression Model
# Linear Regression fits a linear model with coefficients B = (B1, ..., Bn) to minimize the 'residual sum of squares' between the independent x in the dataset, and the dependent y by the linear approximation.

# %% [markdown]
# #### Train data distribution

# %%
plt.scatter(training_set.ENGINESIZE, training_set.CO2EMISSIONS,  color='blue')
plt.xlabel("Engine size")
plt.ylabel("Emission")
plt.show()

# %%
plt.scatter(testing_set.ENGINESIZE, testing_set.CO2EMISSIONS,  color='blue')
plt.xlabel("Engine size")
plt.ylabel("Emission")
plt.show()

# %% [markdown]
# #### Modeling
# Using sklearn package to model data.

# %%
from sklearn import linear_model

# %%
regr = linear_model.LinearRegression()
train_x =np.asanyarray(data_frame[['ENGINESIZE']])
train_y = np.asanyarray(data_frame[['CO2EMISSIONS']])
regr.fit(train_x, train_y)

# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ', regr.intercept_)
# Out:
# Coefficients:  [[39.12519979]]
# Intercept:  [125.3040995]

# %% [markdown]
# As mentioned before, __Coefficient__ and __Intercept__ in the simple linear regression, are the parameters of the fit line.
# Given that it is a simple linear regression, with only 2 parameters, and knowing that the parameters are the intercept and slope of the line, sklearn can estimate them directly from our data.
# Notice that all of the data must be available to traverse and calculate the parameters.

# %%
plt.scatter(training_set.ENGINESIZE, training_set.CO2EMISSIONS, color='blue')
plt.plot(train_x, regr.coef_[0][0]*train_x + regr.intercept_[0], '-r')
plt.xlabel("Engine size")
plt.ylabel("Emission")
# Out:
# Text(0,0.5,'Emission')

# %% [markdown]
# #### Evaluation
# we compare the actual values and predicted values to calculate the accuracy of a regression model. Evaluation metrics provide a key role in the development of a model, as it provides insight to areas that require improvement.
#
# There are different model evaluation metrics, lets use MSE here to calculate the accuracy of our model based on the test set:
#     - Mean absolute error: It is the mean of the absolute value of the errors. This is the easiest of the metrics to understand since it’s just average error.
#     - Mean Squared Error (MSE): Mean Squared Error (MSE) is the mean of the squared error. It’s more popular than Mean absolute error because the focus is geared more towards large errors. This is due to the squared term exponentially increasing larger errors in comparison to smaller ones.
#     - Root Mean Squared Error (RMSE).
#     - R-squared is not error, but is a popular metric for accuracy of your model. It represents how close the data are to the fitted regression line. The higher the R-squared, the better the model fits your data. Best possible score is 1.0 and it can be negative (because the model can be arbitrarily worse).

# %%
from sklearn.metrics import r2_score

test_x = np.asanyarray(testing_set[['ENGINESIZE']])

test_y = np.asanyarray(testing_set[['CO2EMISSIONS']])
test_y_ = regr.predict(test_x)
mean_absolute_error = np.mean(np.absolute(test_y_ - test_y))
print("Mean absolute error : %.2f" % np.mean(np.absolute(test_y_ - test_y)))
print("Residula sum of square (MSE): %.2f" % mean_absolute_error**2)
print("R2-score: %.2f" % r2_score(test_y_ , test_y))
# Out:
# Mean absolute error : 22.69
# Residula sum of square (MSE): 514.99
# R2-score: 0.74
